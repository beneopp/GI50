# %%
import pandas as pd
import numpy as np

# %%
f = "../data/cell_line/dists.csv"
df = pd.read_csv(f)

# %%
df
# Out:
#         Unnamed: 0     BR:MCF7  BR:MDA-MB-231   BR:HS 578T    BR:BT-549  \
# 0          BR:MCF7    0.000000     738.463294   721.770286   885.196957
# 1    BR:MDA-MB-231  738.463294       0.000000   717.466354   990.526321
# 2       BR:HS 578T  721.770286     717.466354     0.000000   917.482701
# 3        BR:BT-549  885.196957     990.526321   917.482701     0.000000
# 4         BR:T-47D  781.970303     817.810331   789.235578   943.549563
# 5       CNS:SF-268  779.881262     789.217721   791.134071   935.418556
# 6       CNS:SF-539  709.876400     758.569303   739.062778   913.373483
# 7       CNS:SNB-19  824.363088     738.681111   770.250396   953.553064
# 8       CNS:SNB-75  745.523088     765.143571   731.307106   901.167383
# 9         CNS:U251  945.151631    1064.153479  1006.708847   951.965728
# 10     CO:COLO 205  838.864191     976.240274   904.216116   845.047756
# 11     CO:HCC-2998  802.912516     943.678630   875.058566   845.909522
# ...

# %%
df.index = df.iloc[:,0]
df = df.iloc[:,1:]
df
# Out:
#                    BR:MCF7  BR:MDA-MB-231   BR:HS 578T    BR:BT-549  \
# Unnamed: 0
# BR:MCF7           0.000000     738.463294   721.770286   885.196957
# BR:MDA-MB-231   738.463294       0.000000   717.466354   990.526321
# BR:HS 578T      721.770286     717.466354     0.000000   917.482701
# BR:BT-549       885.196957     990.526321   917.482701     0.000000
# BR:T-47D        781.970303     817.810331   789.235578   943.549563
# CNS:SF-268      779.881262     789.217721   791.134071   935.418556
# CNS:SF-539      709.876400     758.569303   739.062778   913.373483
# CNS:SNB-19      824.363088     738.681111   770.250396   953.553064
# CNS:SNB-75      745.523088     765.143571   731.307106   901.167383
# CNS:U251        945.151631    1064.153479  1006.708847   951.965728
# CO:COLO 205     838.864191     976.240274   904.216116   845.047756
# CO:HCC-2998     802.912516     943.678630   875.058566   845.909522
# CO:HCT-116      821.163019     984.426909   889.847305   817.152412
# ...

# %%
sim_df = 1 / (df + 1)
sim_df
# Out:
#                  BR:MCF7  BR:MDA-MB-231  BR:HS 578T  BR:BT-549  BR:T-47D  \
# Unnamed: 0
# BR:MCF7         1.000000       0.001352    0.001384   0.001128  0.001277
# BR:MDA-MB-231   0.001352       1.000000    0.001392   0.001009  0.001221
# BR:HS 578T      0.001384       0.001392    1.000000   0.001089  0.001265
# BR:BT-549       0.001128       0.001009    0.001089   1.000000  0.001059
# BR:T-47D        0.001277       0.001221    0.001265   0.001059  1.000000
# CNS:SF-268      0.001281       0.001265    0.001262   0.001068  0.001251
# CNS:SF-539      0.001407       0.001317    0.001351   0.001094  0.001295
# CNS:SNB-19      0.001212       0.001352    0.001297   0.001048  0.001277
# CNS:SNB-75      0.001340       0.001305    0.001366   0.001108  0.001201
# CNS:U251        0.001057       0.000939    0.000992   0.001049  0.000954
# CO:COLO 205     0.001191       0.001023    0.001105   0.001182  0.001069
# CO:HCC-2998     0.001244       0.001059    0.001141   0.001181  0.001164
# ...

# %%
np.min(sim_df.to_numpy(dtype=float))
# Out:
# 0.0008916074736292661
